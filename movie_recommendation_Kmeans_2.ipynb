# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import ast

# %%
movies = pd.read_csv('/content/drive/MyDrive/Movie Dataset/tmdb_5000_movies.csv')
credits = pd.read_csv('/content/drive/MyDrive/Movie Dataset/tmdb_5000_credits.csv')

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
# 2  A cryptic message from Bond’s past sends him o...  107.376788
# 3  Following the death of District Attorney Harve...  112.312950
# 4  John Carter is a war-weary, former military ca...   43.926995
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...
# 4        [{"name": "Walt Disney Pictures", "id": 2}]
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
# 2  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26   880674609
# 3  [{"iso_3166_1": "US", "name": "United States o...   2012-07-16  1084939099
# 4  [{"iso_3166_1": "US", "name": "United States o...   2012-03-07   284139100
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 2    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3    165.0           [{"iso_639_1": "en", "name": "English"}]  Released
# 4    132.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500
# 2                                   Spectre           6.3        4466
# 3                     The Dark Knight Rises           7.6        9106
# 4                               John Carter           6.1        2124

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
movies = movies.merge(credits, on='title')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4809 non-null   int64
#  1   genres                4809 non-null   object
#  2   homepage              1713 non-null   object
#  3   id                    4809 non-null   int64
#  4   keywords              4809 non-null   object
#  5   original_language     4809 non-null   object
#  6   original_title        4809 non-null   object
#  7   overview              4806 non-null   object
#  8   popularity            4809 non-null   float64
#  9   production_companies  4809 non-null   object
#  10  production_countries  4809 non-null   object
#  11  release_date          4808 non-null   object
#  12  revenue               4809 non-null   int64
#  13  runtime               4807 non-null   float64
#  14  spoken_languages      4809 non-null   object
#  15  status                4809 non-null   object
#  16  tagline               3965 non-null   object
#  17  title                 4809 non-null   object
#  18  vote_average          4809 non-null   float64
#  19  vote_count            4809 non-null   int64
#  20  movie_id              4809 non-null   int64
#  21  cast                  4809 non-null   object
#  22  crew                  4809 non-null   object
# dtypes: float64(3), int64(5), object(15)
# memory usage: 901.7+ KB

# %%
#taking only gener id keywords title overview cast crew
movies = movies[['movie_id','title','genres','keywords','cast','crew']]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4809 entries, 0 to 4808
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4809 non-null   int64
#  1   title     4809 non-null   object
#  2   genres    4809 non-null   object
#  3   keywords  4809 non-null   object
#  4   cast      4809 non-null   object
#  5   crew      4809 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 263.0+ KB

# %%
movies.isnull().sum()
# Out:
# movie_id    0
# title       0
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
movies.dropna(inplace=True)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4809 entries, 0 to 4808
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4809 non-null   int64
#  1   title     4809 non-null   object
#  2   genres    4809 non-null   object
#  3   keywords  4809 non-null   object
#  4   cast      4809 non-null   object
#  5   crew      4809 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 263.0+ KB

# %%
#converting dictionary to list
def convert(text):
    L = []
    for i in ast.literal_eval(text):
        L.append(i['name'])
    return L

# %%
movies['genres'] = movies['genres'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
movies['keywords'] = movies['keywords'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
movies['cast'] = movies['cast'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                                 cast  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 1  [Johnny Depp, Orlando Bloom, Keira Knightley, ...
# 2  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...
# 3  [Christian Bale, Michael Caine, Gary Oldman, A...
# 4  [Taylor Kitsch, Lynn Collins, Samantha Morton,...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
#taking only first three actors
movies['cast'] = movies['cast'].apply(lambda x: x[:3])
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                                cast  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley]
# 2      [Daniel Craig, Christoph Waltz, Léa Seydoux]
# 3      [Christian Bale, Michael Caine, Gary Oldman]
# 4    [Taylor Kitsch, Lynn Collins, Samantha Morton]
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
# Function to fetch director names
def fetch_director(text):
    L = []
    for i in ast.literal_eval(text):
        if i['job'] == 'Director':
            L.append(i['name'])
    return L

# %%
#taking only directors as a crew
movies['crew'] = movies['crew'].apply(fetch_director)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                                cast                 crew
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]      [James Cameron]
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley]     [Gore Verbinski]
# 2      [Daniel Craig, Christoph Waltz, Léa Seydoux]         [Sam Mendes]
# 3      [Christian Bale, Michael Caine, Gary Oldman]  [Christopher Nolan]
# 4    [Taylor Kitsch, Lynn Collins, Samantha Morton]     [Andrew Stanton]

# %%
#removing space
def collapse(L):
    L1 = [i.replace(" ", "") for i in L]
    return L1

# %%
movies['cast'] = movies['cast'].apply(collapse)
movies['crew'] = movies['crew'].apply(collapse)
movies['genres'] = movies['genres'].apply(collapse)
movies['keywords'] = movies['keywords'].apply(collapse)

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3  [dccomics, crimefighter, terrorist, secretiden...
# 4  [basedonnovel, mars, medallion, spacetravel, p...
#
#                                             cast                crew
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]      [JamesCameron]
# 1     [JohnnyDepp, OrlandoBloom, KeiraKnightley]     [GoreVerbinski]
# 2      [DanielCraig, ChristophWaltz, LéaSeydoux]         [SamMendes]
# 3      [ChristianBale, MichaelCaine, GaryOldman]  [ChristopherNolan]
# 4    [TaylorKitsch, LynnCollins, SamanthaMorton]     [AndrewStanton]

# %%
movies['tags'] = movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3  [dccomics, crimefighter, terrorist, secretiden...
# 4  [basedonnovel, mars, medallion, spacetravel, p...
#
#                                             cast                crew  \
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]      [JamesCameron]
# 1     [JohnnyDepp, OrlandoBloom, KeiraKnightley]     [GoreVerbinski]
# 2      [DanielCraig, ChristophWaltz, LéaSeydoux]         [SamMendes]
# 3      [ChristianBale, MichaelCaine, GaryOldman]  [ChristopherNolan]
# 4    [TaylorKitsch, LynnCollins, SamanthaMorton]     [AndrewStanton]
#
#                                                 tags
# 0  [Action, Adventure, Fantasy, ScienceFiction, c...
# 1  [Adventure, Fantasy, Action, ocean, drugabuse,...
# 2  [Action, Adventure, Crime, spy, basedonnovel, ...
# 3  [Action, Crime, Drama, Thriller, dccomics, cri...
# 4  [Action, Adventure, ScienceFiction, basedonnov...

# %%
# Combined the tags into a single string
movies['tags'] = movies['tags'].apply(lambda x: " ".join(x))
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3  [dccomics, crimefighter, terrorist, secretiden...
# 4  [basedonnovel, mars, medallion, spacetravel, p...
#
#                                             cast                crew  \
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]      [JamesCameron]
# 1     [JohnnyDepp, OrlandoBloom, KeiraKnightley]     [GoreVerbinski]
# 2      [DanielCraig, ChristophWaltz, LéaSeydoux]         [SamMendes]
# 3      [ChristianBale, MichaelCaine, GaryOldman]  [ChristopherNolan]
# 4    [TaylorKitsch, LynnCollins, SamanthaMorton]     [AndrewStanton]
#
#                                                 tags
# 0  Action Adventure Fantasy ScienceFiction cultur...
# 1  Adventure Fantasy Action ocean drugabuse exoti...
# 2  Action Adventure Crime spy basedonnovel secret...
# 3  Action Crime Drama Thriller dccomics crimefigh...
# 4  Action Adventure ScienceFiction basedonnovel m...

# %%
tfidf = TfidfVectorizer(max_features=5000, stop_words='english')
tfidf_matrix = tfidf.fit_transform(movies['tags'])

# %%
# Applying KMeans clustering
k = 500  # Number of clusters
kmeans = KMeans(n_clusters=k, n_init=5, random_state=42)
kmeans.fit(tfidf_matrix)
# Out:
# KMeans(n_clusters=500, n_init=5, random_state=42)

# %%
# Adding the predicted clusters to the movies DataFrame
movies['cluster'] = kmeans.labels_

# %%
def recommend_movies_kmeans(movie_title):
    # Find the movie index
    movie_index = movies[movies['title'] == movie_title].index[0]

    # Extract the cluster of the input movie
    movie_cluster = movies.iloc[movie_index]['cluster']

    # Find all movies in the same cluster, excluding the input movie
    recommended_movies = movies[movies['cluster'] == movie_cluster]
    recommended_movies = recommended_movies[recommended_movies['title'] != movie_title]['title']

    # Limit recommendations to a maximum of 5 movies
    recommended_movies = recommended_movies.head(5)

    return recommended_movies

# %%
def recommend_movies(movie_title):
    recommended_movies = recommend_movies_kmeans(movie_title)
    if recommended_movies.empty:
        print("No recommendations found.")
    else:
        print(f"Recommended Movies based on '{movie_title}':")
        for movie in recommended_movies:
            print(movie)

# %%
recommend_movies('Interstellar')
# Out:
# Recommended Movies based on 'Interstellar':
# Avatar
# Spectre
# The Dark Knight Rises
# Spider-Man 3
# Quantum of Solace

# %%
recommend_movies('Captain America: The Winter Soldier')
# Out:
# Recommended Movies based on 'Captain America: The Winter Soldier':
# Captain America: Civil War

# %%
recommend_movies('Guardians of the Galaxy')
# Out:
# Recommended Movies based on 'Guardians of the Galaxy':
# Avatar
# Spectre
# The Dark Knight Rises
# Spider-Man 3
# Quantum of Solace

# %%
# Calculate silhouette score
silhouette_avg = silhouette_score(tfidf_matrix, kmeans.labels_)
print(f"The average silhouette_score for {k} clusters is: {silhouette_avg}")
# Out:
# The average silhouette_score for 500 clusters is: -0.03805319618980422

# %%
def find_best_cluster(data, max_clusters):
    best_score = -1
    best_cluster = 0

    for n_clusters in range(400, max_clusters + 1, 20):
        kmeans = KMeans(n_clusters=n_clusters, n_init=5, random_state=42)
        kmeans.fit(tfidf_matrix)
        silhouette_avg = silhouette_score(data, kmeans.labels_)
        print(f"For n_clusters = {n_clusters}, the average silhouette_score is: {silhouette_avg}")

        if silhouette_avg > best_score:
            best_score = silhouette_avg
            best_cluster = n_clusters

    return best_cluster, best_score

best_cluster, best_score = find_best_cluster(tfidf_matrix, 4500)
print(f"The best number of clusters is {best_cluster} with a silhouette score of {best_score}")
# Out:
# For n_clusters = 400, the average silhouette_score is: -0.03673006264855899
# For n_clusters = 420, the average silhouette_score is: -0.0358961365816262
# For n_clusters = 440, the average silhouette_score is: -0.03937569686022237
# For n_clusters = 460, the average silhouette_score is: -0.04007353897978039
# For n_clusters = 480, the average silhouette_score is: -0.04313538226688373
# For n_clusters = 500, the average silhouette_score is: -0.03805319618980422
# For n_clusters = 520, the average silhouette_score is: -0.0394770697055363
# For n_clusters = 540, the average silhouette_score is: -0.039161062960686596
# For n_clusters = 560, the average silhouette_score is: -0.03894800091447183
# For n_clusters = 580, the average silhouette_score is: -0.039058130969398905
# For n_clusters = 600, the average silhouette_score is: -0.039190841779805835
# For n_clusters = 620, the average silhouette_score is: -0.040058055430564544
# For n_clusters = 640, the average silhouette_score is: -0.038430436925688226
# For n_clusters = 660, the average silhouette_score is: -0.039285631939862675
# For n_clusters = 680, the average silhouette_score is: -0.03977229372978619
# For n_clusters = 700, the average silhouette_score is: -0.03827569588136241
# For n_clusters = 720, the average silhouette_score is: -0.038667336195034895
# For n_clusters = 740, the average silhouette_score is: -0.036062687365490176
# For n_clusters = 760, the average silhouette_score is: -0.03798597334174809
# For n_clusters = 780, the average silhouette_score is: -0.03879246676426568
# For n_clusters = 800, the average silhouette_score is: -0.037809868773910967
# For n_clusters = 820, the average silhouette_score is: -0.037913267283575185
# For n_clusters = 840, the average silhouette_score is: -0.03768376165747259
# For n_clusters = 860, the average silhouette_score is: -0.03986267771539944
# For n_clusters = 880, the average silhouette_score is: -0.03753891475181011
# For n_clusters = 900, the average silhouette_score is: -0.03783524077433158
# For n_clusters = 920, the average silhouette_score is: -0.038336021612595875
# For n_clusters = 940, the average silhouette_score is: -0.03786493130525396
# For n_clusters = 960, the average silhouette_score is: -0.03933557747790827
# For n_clusters = 980, the average silhouette_score is: -0.03711815425353254
# For n_clusters = 1000, the average silhouette_score is: -0.03967047928231335
# For n_clusters = 1020, the average silhouette_score is: -0.03555694347526286
# For n_clusters = 1040, the average silhouette_score is: -0.03855560186577197
# For n_clusters = 1060, the average silhouette_score is: -0.03586412730618797
# For n_clusters = 1080, the average silhouette_score is: -0.036952890616146775
# For n_clusters = 1100, the average silhouette_score is: -0.036928361737835765
# For n_clusters = 1120, the average silhouette_score is: -0.03652214720138568
# For n_clusters = 1140, the average silhouette_score is: -0.03770178716024884
# For n_clusters = 1160, the average silhouette_score is: -0.03539037716824885
# For n_clusters = 1180, the average silhouette_score is: -0.035613345852711246
# For n_clusters = 1200, the average silhouette_score is: -0.033662693186907046
# For n_clusters = 1220, the average silhouette_score is: -0.034985176517309605
# For n_clusters = 1240, the average silhouette_score is: -0.03622274798143286
# For n_clusters = 1260, the average silhouette_score is: -0.03561923108050756
# For n_clusters = 1280, the average silhouette_score is: -0.03517091338461396
# For n_clusters = 1300, the average silhouette_score is: -0.03413628939622094
# For n_clusters = 1320, the average silhouette_score is: -0.03505411676684844
# For n_clusters = 1340, the average silhouette_score is: -0.03496012411516389
# For n_clusters = 1360, the average silhouette_score is: -0.034056476492035546
# For n_clusters = 1380, the average silhouette_score is: -0.03321630902687411
# For n_clusters = 1400, the average silhouette_score is: -0.03406105454223631
# For n_clusters = 1420, the average silhouette_score is: -0.034022801041723255
# For n_clusters = 1440, the average silhouette_score is: -0.03294922616701991
# For n_clusters = 1460, the average silhouette_score is: -0.034180959529577136
# For n_clusters = 1480, the average silhouette_score is: -0.033441127728209535
# For n_clusters = 1500, the average silhouette_score is: -0.03300641418120364
# For n_clusters = 1520, the average silhouette_score is: -0.032106747955360004
# For n_clusters = 1540, the average silhouette_score is: -0.032557427694084394
# For n_clusters = 1560, the average silhouette_score is: -0.03204558683801544
# For n_clusters = 1580, the average silhouette_score is: -0.031803732253509825
# For n_clusters = 1600, the average silhouette_score is: -0.03133130247457836
# For n_clusters = 1620, the average silhouette_score is: -0.03144862318584553
# For n_clusters = 1640, the average silhouette_score is: -0.03112761006631567
# For n_clusters = 1660, the average silhouette_score is: -0.030948742142431204
# For n_clusters = 1680, the average silhouette_score is: -0.030597568389308164
# For n_clusters = 1700, the average silhouette_score is: -0.029829247000004337
# For n_clusters = 1720, the average silhouette_score is: -0.029207248900312937
# For n_clusters = 1740, the average silhouette_score is: -0.0300241558425259
# For n_clusters = 1760, the average silhouette_score is: -0.02961845983551458
# For n_clusters = 1780, the average silhouette_score is: -0.02754655124559122
# For n_clusters = 1800, the average silhouette_score is: -0.029574536596115076
# For n_clusters = 1820, the average silhouette_score is: -0.029678352108989434
# For n_clusters = 1840, the average silhouette_score is: -0.02700175710638496
# For n_clusters = 1860, the average silhouette_score is: -0.028340187719698668
# For n_clusters = 1880, the average silhouette_score is: -0.027195286320131348
# For n_clusters = 1900, the average silhouette_score is: -0.025943387906562206
# For n_clusters = 1920, the average silhouette_score is: -0.026123523927108417
# For n_clusters = 1940, the average silhouette_score is: -0.027562180359260155
# For n_clusters = 1960, the average silhouette_score is: -0.02673271816681243
# For n_clusters = 1980, the average silhouette_score is: -0.025190634521027516
# For n_clusters = 2000, the average silhouette_score is: -0.025809324844395673
# For n_clusters = 2020, the average silhouette_score is: -0.024714784104057377
# For n_clusters = 2040, the average silhouette_score is: -0.023865922012546663
# For n_clusters = 2060, the average silhouette_score is: -0.022869561618349177
# For n_clusters = 2080, the average silhouette_score is: -0.023034955445256355
# For n_clusters = 2100, the average silhouette_score is: -0.023612547225025766
# For n_clusters = 2120, the average silhouette_score is: -0.023121459304202906
# For n_clusters = 2140, the average silhouette_score is: -0.02305206525548105
# For n_clusters = 2160, the average silhouette_score is: -0.021555628118146156
# For n_clusters = 2180, the average silhouette_score is: -0.02293059337431504
# For n_clusters = 2200, the average silhouette_score is: -0.02253512213216022
# For n_clusters = 2220, the average silhouette_score is: -0.022014997511569358
# For n_clusters = 2240, the average silhouette_score is: -0.020075326648231914
# For n_clusters = 2260, the average silhouette_score is: -0.018895010765028808
# For n_clusters = 2280, the average silhouette_score is: -0.020467293305888166
# For n_clusters = 2300, the average silhouette_score is: -0.019008343518071506
# For n_clusters = 2320, the average silhouette_score is: -0.018472237773581788
# For n_clusters = 2340, the average silhouette_score is: -0.018872226224272405
# For n_clusters = 2360, the average silhouette_score is: -0.01866796929727891
# For n_clusters = 2380, the average silhouette_score is: -0.018122090723705325
# For n_clusters = 2400, the average silhouette_score is: -0.01705638274027359
# For n_clusters = 2420, the average silhouette_score is: -0.01702892943690988
# For n_clusters = 2440, the average silhouette_score is: -0.01579121427871295
# For n_clusters = 2460, the average silhouette_score is: -0.01609062037014166
# For n_clusters = 2480, the average silhouette_score is: -0.015246613259688516
# For n_clusters = 2500, the average silhouette_score is: -0.014713613993104592
# For n_clusters = 2520, the average silhouette_score is: -0.013792476685080213
# For n_clusters = 2540, the average silhouette_score is: -0.012938586639055895
# For n_clusters = 2560, the average silhouette_score is: -0.012045973547607879
# For n_clusters = 2580, the average silhouette_score is: -0.011778570214538276
# For n_clusters = 2600, the average silhouette_score is: -0.011548195687768156
# For n_clusters = 2620, the average silhouette_score is: -0.011090000294259397
# For n_clusters = 2640, the average silhouette_score is: -0.010959980165666898
# For n_clusters = 2660, the average silhouette_score is: -0.010653194042426426
# For n_clusters = 2680, the average silhouette_score is: -0.00988239594423541
# For n_clusters = 2700, the average silhouette_score is: -0.009983833310620438
# For n_clusters = 2720, the average silhouette_score is: -0.009969340769453836
# For n_clusters = 2740, the average silhouette_score is: -0.008422784545366218
# For n_clusters = 2760, the average silhouette_score is: -0.007794861740683211
# For n_clusters = 2780, the average silhouette_score is: -0.006958636255640455
# For n_clusters = 2800, the average silhouette_score is: -0.007009060832169654
# For n_clusters = 2820, the average silhouette_score is: -0.006635347058274178
# For n_clusters = 2840, the average silhouette_score is: -0.004842179439965712
# For n_clusters = 2860, the average silhouette_score is: -0.004731755943175406
# For n_clusters = 2880, the average silhouette_score is: -0.005127850392579231
# For n_clusters = 2900, the average silhouette_score is: -0.0046717483857205274
# For n_clusters = 2920, the average silhouette_score is: -0.004203075602516711
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-d5bae9f5d3f3> in <cell line: 17>()
#      15     return best_cluster, best_score
#      16
# ---> 17 best_cluster, best_score = find_best_cluster(tfidf_matrix, 4500)
#      18 print(f"The best number of clusters is {best_cluster} with a silhouette score of {best_score}")
#
# <ipython-input-27-d5bae9f5d3f3> in find_best_cluster(data, max_clusters)
#       5     for n_clusters in range(400, max_clusters + 1, 20):
#       6         kmeans = KMeans(n_clusters=n_clusters, n_init=5, random_state=42)
# ----> 7         kmeans.fit(tfidf_matrix)
#       8         silhouette_avg = silhouette_score(data, kmeans.labels_)
#       9         print(f"For n_clusters = {n_clusters}, the average silhouette_score is: {silhouette_avg}")
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#    1466
#    1467             # run a k-means once
# -> 1468             labels, inertia, centers, n_iter_ = kmeans_single(
#    1469                 X,
#    1470                 sample_weight,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py in _kmeans_single_lloyd(X, sample_weight, centers_init, max_iter, verbose, tol, n_threads)
#     729             )
#     730
# --> 731     inertia = _inertia(X, sample_weight, centers, labels, n_threads)
#     732
#     733     return labels, inertia, centers, i + 1
#
# KeyboardInterrupt:

# %%
def find_best_cluster(data, max_clusters):
    best_score = -1
    best_cluster = 0

    for n_clusters in range(2920, max_clusters + 1, 20):
        kmeans = KMeans(n_clusters=n_clusters, n_init=5, random_state=42)
        kmeans.fit(tfidf_matrix)
        silhouette_avg = silhouette_score(data, kmeans.labels_)
        print(f"For n_clusters = {n_clusters}, the average silhouette_score is: {silhouette_avg}")

        if silhouette_avg > best_score:
            best_score = silhouette_avg
            best_cluster = n_clusters

    return best_cluster, best_score

best_cluster, best_score = find_best_cluster(tfidf_matrix, 4500)
print(f"The best number of clusters is {best_cluster} with a silhouette score of {best_score}")
# Out:
# For n_clusters = 2920, the average silhouette_score is: -0.004203075602516711
# For n_clusters = 2940, the average silhouette_score is: -0.0024329915020803263
# For n_clusters = 2960, the average silhouette_score is: -0.0031093435874730577
# For n_clusters = 2980, the average silhouette_score is: -0.0011972717904835286
# For n_clusters = 3000, the average silhouette_score is: -0.0022842106455548154
# For n_clusters = 3020, the average silhouette_score is: -0.0017061315630124473
# For n_clusters = 3040, the average silhouette_score is: -0.0011406338998878117
# For n_clusters = 3060, the average silhouette_score is: -0.0005994190866690354
# For n_clusters = 3080, the average silhouette_score is: 4.907997013575006e-05
# For n_clusters = 3100, the average silhouette_score is: 0.0005762466635855992
# For n_clusters = 3120, the average silhouette_score is: 0.0011345529732799543
# For n_clusters = 3140, the average silhouette_score is: 0.0015906834806583606
# For n_clusters = 3160, the average silhouette_score is: 0.002095892823484647
# For n_clusters = 3180, the average silhouette_score is: 0.002666255491176603
# For n_clusters = 3200, the average silhouette_score is: 0.003152331373062617
# For n_clusters = 3220, the average silhouette_score is: 0.005222265011699865
# For n_clusters = 3240, the average silhouette_score is: 0.00408953324653059
# For n_clusters = 3260, the average silhouette_score is: 0.006073284445913081
# For n_clusters = 3280, the average silhouette_score is: 0.0053271625600669285
# For n_clusters = 3300, the average silhouette_score is: 0.007371309023546342
# For n_clusters = 3320, the average silhouette_score is: 0.006374850903722934
# For n_clusters = 3340, the average silhouette_score is: 0.006986764319673564
# For n_clusters = 3360, the average silhouette_score is: 0.007512646638289695
# For n_clusters = 3380, the average silhouette_score is: 0.008126824142246426
# For n_clusters = 3400, the average silhouette_score is: 0.00840793319058605
# For n_clusters = 3420, the average silhouette_score is: 0.008962812352746426
# For n_clusters = 3440, the average silhouette_score is: 0.010417107904108965
# For n_clusters = 3460, the average silhouette_score is: 0.01003492062052677
# For n_clusters = 3480, the average silhouette_score is: 0.01221618039680417
# For n_clusters = 3500, the average silhouette_score is: 0.012624685110049943
# For n_clusters = 3520, the average silhouette_score is: 0.014027012165803028
# For n_clusters = 3540, the average silhouette_score is: 0.01355426096481348
# For n_clusters = 3560, the average silhouette_score is: 0.013997568086555239
# For n_clusters = 3580, the average silhouette_score is: 0.015242987810835955
# For n_clusters = 3600, the average silhouette_score is: 0.016590967119686884
# For n_clusters = 3620, the average silhouette_score is: 0.01606541813032838
# For n_clusters = 3640, the average silhouette_score is: 0.01606064851872206
# For n_clusters = 3660, the average silhouette_score is: 0.01628198035493448
# For n_clusters = 3680, the average silhouette_score is: 0.01691898004889526
# For n_clusters = 3700, the average silhouette_score is: 0.017508715637397206
# For n_clusters = 3720, the average silhouette_score is: 0.017877494450852138
# For n_clusters = 3740, the average silhouette_score is: 0.0205650760919013
# For n_clusters = 3760, the average silhouette_score is: 0.02076827846738579
# For n_clusters = 3780, the average silhouette_score is: 0.01964142206693433
# For n_clusters = 3800, the average silhouette_score is: 0.021669124065103757
# For n_clusters = 3820, the average silhouette_score is: 0.02157343740783595
# For n_clusters = 3840, the average silhouette_score is: 0.022640865372069024
# For n_clusters = 3860, the average silhouette_score is: 0.024091253161698623
# For n_clusters = 3880, the average silhouette_score is: 0.024573493304216737
# For n_clusters = 3900, the average silhouette_score is: 0.025213682419051073
# For n_clusters = 3920, the average silhouette_score is: 0.025935904951291534
# For n_clusters = 3940, the average silhouette_score is: 0.02612087751023487
# For n_clusters = 3960, the average silhouette_score is: 0.02759369263832736
# For n_clusters = 3980, the average silhouette_score is: 0.027411708404311272
# For n_clusters = 4000, the average silhouette_score is: 0.027805708391936232
# For n_clusters = 4020, the average silhouette_score is: 0.02771065971275395
# For n_clusters = 4040, the average silhouette_score is: 0.030125832611492712
# For n_clusters = 4060, the average silhouette_score is: 0.030547047386427023
# For n_clusters = 4080, the average silhouette_score is: 0.03057132095007498
# For n_clusters = 4100, the average silhouette_score is: 0.03173431313651508
# For n_clusters = 4120, the average silhouette_score is: 0.03271302174379082
# For n_clusters = 4140, the average silhouette_score is: 0.03278728817161151
# For n_clusters = 4160, the average silhouette_score is: 0.032921638675802216
# For n_clusters = 4180, the average silhouette_score is: 0.03474149210538704
# For n_clusters = 4200, the average silhouette_score is: 0.0352561897004295
# For n_clusters = 4220, the average silhouette_score is: 0.034667581188835686
# For n_clusters = 4240, the average silhouette_score is: 0.036005687935124285
# For n_clusters = 4260, the average silhouette_score is: 0.03730547893654757
# For n_clusters = 4280, the average silhouette_score is: 0.037585913578674746
# For n_clusters = 4300, the average silhouette_score is: 0.03813956446932316
# For n_clusters = 4320, the average silhouette_score is: 0.035365621608437064
# For n_clusters = 4340, the average silhouette_score is: 0.03466197414603003
# For n_clusters = 4360, the average silhouette_score is: 0.03486155896435635
# For n_clusters = 4380, the average silhouette_score is: 0.03377341161513065
# For n_clusters = 4400, the average silhouette_score is: 0.03206782916709248
# For n_clusters = 4420, the average silhouette_score is: 0.03170049756385797
# For n_clusters = 4440, the average silhouette_score is: 0.03233488085493888
# For n_clusters = 4460, the average silhouette_score is: 0.03216500996000452
# For n_clusters = 4480, the average silhouette_score is: 0.03184197863030763
# For n_clusters = 4500, the average silhouette_score is: 0.03284119390893605
# The best number of clusters is 4300 with a silhouette score of 0.03813956446932316

# %%
# Applying KMeans clustering
k = 4300  # Number of clusters
kmeans = KMeans(n_clusters=k, n_init=5, random_state=42)
kmeans.fit(tfidf_matrix)
# Out:
# KMeans(n_clusters=4300, n_init=5, random_state=42)

# %%
# Adding the predicted clusters to the movies DataFrame
movies['cluster'] = kmeans.labels_

# %%
def recommend_movies(movie_title):
    recommended_movies = recommend_movies_kmeans(movie_title)
    if recommended_movies.empty:
        print("No recommendations found.")
    else:
        print(f"Recommended Movies based on '{movie_title}':")
        for movie in recommended_movies:
            print(movie)

# %%
def recommend_movies_kmeans(movie_title):
    # Find the movie index
    movie_index = movies[movies['title'] == movie_title].index[0]

    # Extract the cluster of the input movie
    movie_cluster = movies.iloc[movie_index]['cluster']

    # Find all movies in the same cluster, excluding the input movie
    recommended_movies = movies[movies['cluster'] == movie_cluster]
    recommended_movies = recommended_movies[recommended_movies['title'] != movie_title]['title']

    # Limit recommendations to a maximum of 5 movies
    recommended_movies = recommended_movies.head(5)

    return recommended_movies

# %%
recommend_movies('Interstellar')
# Out:
# No recommendations found.

# %%
recommend_movies('Captain America: The Winter Soldier')
# Out:
# Recommended Movies based on 'Captain America: The Winter Soldier':
# Captain America: Civil War

# %%
recommend_movies('Titanic')
# Out:
# No recommendations found.
