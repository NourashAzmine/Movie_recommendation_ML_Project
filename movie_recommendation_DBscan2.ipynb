# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np

import ast

# %%
movies = pd.read_csv('/content/drive/MyDrive/Movie Dataset/tmdb_5000_movies.csv')
credits = pd.read_csv('/content/drive/MyDrive/Movie Dataset/tmdb_5000_credits.csv')

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
movies = movies.merge(credits, on='title')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4809 non-null   int64
#  1   genres                4809 non-null   object
#  2   homepage              1713 non-null   object
#  3   id                    4809 non-null   int64
#  4   keywords              4809 non-null   object
#  5   original_language     4809 non-null   object
#  6   original_title        4809 non-null   object
#  7   overview              4806 non-null   object
#  8   popularity            4809 non-null   float64
#  9   production_companies  4809 non-null   object
#  10  production_countries  4809 non-null   object
#  11  release_date          4808 non-null   object
#  12  revenue               4809 non-null   int64
#  13  runtime               4807 non-null   float64
#  14  spoken_languages      4809 non-null   object
# ...

# %%
#taking only gener id keywords title overview cast crew
movies = movies[['movie_id','title','overview','genres','keywords','cast','crew']]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4809 entries, 0 to 4808
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4809 non-null   int64
#  1   title     4809 non-null   object
#  2   overview  4806 non-null   object
#  3   genres    4809 non-null   object
#  4   keywords  4809 non-null   object
#  5   cast      4809 non-null   object
#  6   crew      4809 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 300.6+ KB

# %%
movies.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    3
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
movies.dropna(inplace=True)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4806 entries, 0 to 4808
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  4806 non-null   int64
#  1   title     4806 non-null   object
#  2   overview  4806 non-null   object
#  3   genres    4806 non-null   object
#  4   keywords  4806 non-null   object
#  5   cast      4806 non-null   object
#  6   crew      4806 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 300.4+ KB

# %%
#converting dictionary to list
def convert(text):
    L = []
    for i in ast.literal_eval(text):
        L.append(i['name'])
    return L

# %%
movies['genres'] = movies['genres'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies['keywords'] = movies['keywords'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
movies['cast'] = movies['cast'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
#taking only first three actors
movies['cast'] = movies['cast'].apply(lambda x: x[:3])
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
# Function to fetch director names
def fetch_director(text):
    L = []
    for i in ast.literal_eval(text):
        if i['job'] == 'Director':
            L.append(i['name'])
    return L

# %%
#taking only directors as a crew
movies['crew'] = movies['crew'].apply(fetch_director)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
#removing space
def collapse(L):
    L1 = [i.replace(" ", "") for i in L]
    return L1

# %%
movies['cast'] = movies['cast'].apply(collapse)
movies['crew'] = movies['crew'].apply(collapse)
movies['genres'] = movies['genres'].apply(collapse)
movies['keywords'] = movies['keywords'].apply(collapse)

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
# ...

# %%
movies['overview'] = movies['overview'].apply(lambda x: x.split())
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']

# %%
# Combined the tags into a single string
movies['tags'] = movies['tags'].apply(lambda x: " ".join(x))
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
# ...

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
# ...

# %%
# Convert text data to a numerical format using TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(movies['tags'])

# %%
# Calculate similarity matrix using cosine similarity
similarity_matrix = cosine_similarity(tfidf_matrix, tfidf_matrix)
np.fill_diagonal(similarity_matrix, 0)

# %%
# Use DBSCAN for clustering
dbscan = DBSCAN(eps=0.001, min_samples=500, metric='precomputed')
dbscan.fit(similarity_matrix)
# Out:
# DBSCAN(eps=0.001, metric='precomputed', min_samples=500)

# %%
# Add cluster labels to the movies DataFrame
movies['cluster'] = dbscan.labels_

# %%
# Function to recommend movies using DBSCAN
def recommend_dbscan(movie):
    movie_index = movies[movies['title'] == movie].index[0]
    cluster_label = movies.iloc[movie_index]['cluster']

    # Extract movies from the same cluster
    cluster_movies = movies[movies['cluster'] == cluster_label]

    # Exclude the input movie from recommendations
    cluster_movies = cluster_movies[cluster_movies['title'] != movie]

    # Randomly shuffle the cluster movies for variety
    cluster_movies = cluster_movies.sample(frac=1)

    # Display recommended movies from the same cluster
    recommended_movies = cluster_movies['title'][:5].tolist()

    return recommended_movies

# %%
def recommend_movies(movie):
    recommend_movies = recommend_dbscan(movie)
    print("Recommended Movies using DBSCAN:")
    for recommended_movie in recommend_movies:
        print(recommended_movie)

# %%
recommend_movies('Interstellar')
# Out:
# Recommended Movies using DBSCAN:
# The Eclipse
# Beat the World
# Marmaduke
# The Return
# The Legend of Suriyothai

# %%
recommend_movies('Titanic')
# Out:
# Recommended Movies using DBSCAN:
# Brick Mansions
# Eye of the Dolphin
# The Damned United
# Transformers
# Freddy's Dead: The Final Nightmare

# %%
recommend_movies('The Conjuring')
# Out:
# Recommended Movies using DBSCAN:
# The Exploding Girl
# WarGames
# The Lone Ranger
# A Nightmare on Elm Street 4: The Dream Master
# The Host

# %%
recommend_movies('Spider-Man')
# Out:
# Recommended Movies using DBSCAN:
# Don Jon
# Me, Myself & Irene
# Spider-Man 2
# The Last Song
# Annabelle

# %%
recommend_movies('The Matrix')
# Out:
# Recommended Movies using DBSCAN:
# Space Dogs
# Highlander
# Under Siege 2: Dark Territory
# Rudderless
# National Treasure

# %%
# Use DBSCAN for clustering
dbscan = DBSCAN(eps=0.1, min_samples=1000, metric='precomputed')
dbscan.fit(similarity_matrix)
# Add cluster labels to the movies DataFrame
movies['cluster'] = dbscan.labels_
# Function to recommend movies using DBSCAN
def recommend_dbscan(movie):
    movie_index = movies[movies['title'] == movie].index[0]
    cluster_label = movies.iloc[movie_index]['cluster']

    # Extract movies from the same cluster
    cluster_movies = movies[movies['cluster'] == cluster_label]

    # Exclude the input movie from recommendations
    cluster_movies = cluster_movies[cluster_movies['title'] != movie]

    # Randomly shuffle the cluster movies for variety
    cluster_movies = cluster_movies.sample(frac=1)

    # Display recommended movies from the same cluster
    recommended_movies = cluster_movies['title'][:5].tolist()

    return recommended_movies
def recommend_movies(movie):
    recommend_movies = recommend_dbscan(movie)
    print("Recommended Movies using DBSCAN:")
    for recommended_movie in recommend_movies:
        print(recommended_movie)

# %%
recommend_movies('Interstellar')
# Out:
# Recommended Movies using DBSCAN:
# The Legend of Zorro
# The Stepfather
# Lone Survivor
# The Trials Of Darryl Hunt
# Four Christmases

# %%
recommend_movies('Titanic')
# Out:
# Recommended Movies using DBSCAN:
# Valiant
# Saw: The Final Chapter
# Happy, Texas
# Sharknado
# Son of the Mask

# %%
recommend_movies('The Conjuring')
# Out:
# Recommended Movies using DBSCAN:
# The Blood of Heroes
# Somewhere in Time
# Frenzy
# Shanghai Calling
# Broken Vessels

# %%
recommend_movies('Spider-Man')
# Out:
# Recommended Movies using DBSCAN:
# The Puffy Chair
# Captain America: Civil War
# Despicable Me 2
# Lake of Fire
# 1408

# %%
recommend_movies('The Matrix')
# Out:
# Recommended Movies using DBSCAN:
# The True Story of Puss 'n Boots
# Rush Hour 3
# No Escape
# Deep Rising
# Groove

# %%
# Use DBSCAN for clustering
dbscan = DBSCAN(eps=0.5, min_samples=1000, metric='precomputed')
dbscan.fit(similarity_matrix)
# Add cluster labels to the movies DataFrame
movies['cluster'] = dbscan.labels_
# Function to recommend movies using DBSCAN
def recommend_dbscan(movie):
    movie_index = movies[movies['title'] == movie].index[0]
    cluster_label = movies.iloc[movie_index]['cluster']

    # Extract movies from the same cluster
    cluster_movies = movies[movies['cluster'] == cluster_label]

    # Exclude the input movie from recommendations
    cluster_movies = cluster_movies[cluster_movies['title'] != movie]

    # Randomly shuffle the cluster movies for variety
    cluster_movies = cluster_movies.sample(frac=1)

    # Display recommended movies from the same cluster
    recommended_movies = cluster_movies['title'][:5].tolist()

    return recommended_movies
def recommend_movies(movie):
    recommend_movies = recommend_dbscan(movie)
    print("Recommended Movies using DBSCAN:")
    for recommended_movie in recommend_movies:
        print(recommended_movie)

# %%
recommend_movies('Interstellar')
# Out:
# Recommended Movies using DBSCAN:
# Return to Me
# Yours, Mine and Ours
# Jeepers Creepers 2
# The Guru
# High Heels and Low Lifes

# %%
recommend_movies('Spider-Man')
# Out:
# Recommended Movies using DBSCAN:
# Juwanna Mann
# The Hit List
# Fool's Gold
# Thunder and the House of Magic
# Bandidas

# %%
recommend_movies('The Matrix')
# Out:
# Recommended Movies using DBSCAN:
# Thr3e
# Trainwreck
# We Were Soldiers
# Road House
# A History of Violence
